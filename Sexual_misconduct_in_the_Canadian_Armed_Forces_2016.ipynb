# %% [markdown]
# <a href="https://colab.research.google.com/github/Balbuenar/AI-Capstone-Project-with-Deep-Learning/blob/master/Sexual_misconduct_in_the_Canadian_Armed_Forces_2016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sexual Misconduct in the Canadian Armed Forces 2016.
#
# This report is based on results from the Survey on Sexual Misconduct in the Canadian Armed Forces that was conducted in 2016 on behalf of the Canadian Armed Forces. From April to June, 2016, active Regula
#
# # Reference:
# Statistics Canada. (2016). *Sexual misconduct in the Canadian Armed Forces, 2016*. Retrieved from https://www150.statcan.gc.ca/n1/pub/85-603-x/85-603-x2016001-eng.htm
#
#
# Create by PO2 Richard Balbuena

# %% [markdown]
# # Sexual assault of Canadian Armed Forces (CAF) Regular Force members in the past 12 months and since joining the Canadian Armed Forces, by sex and type of sexual assault, 2016
#
# Respondents were asked about their experiences in the 12 months preceding the survey (since April 2015), as well as their experiences prior to April 2015 but since joining the Canadian Armed Forces (CAF). This could mean that some incidents may have occurred as far back as the 1970s, considering the minimum age of entry into the CAF and the mandatory retirement age. At the same time, it is important to recognize that the survey results reflect only the experiences of those still active within the CAF,Note4 and do not include those who have left the CAF for any reason, such as those who may have experienced victimization.
#
# Sexual assault is more prevalent in the CAF than in the general population. Overall, 1.7% of Regular Force members reported that they were victims of sexual assault in the military workplace or involving military members in the 12 months preceding the survey (Table 1; Chart 1). This represented approximately 960 active Regular Force members. In contrast, according to the General Social Survey on Victimization (GSS), 0.9% of Canadians between the ages of 15 and 60 years of age who were active in the labour market were victims of sexual assault in the past year.Note5 The GSS asked about all experiences of sexual assault in the past 12 months and was not limited to incidents which occurred in the workplace or involved coworkers.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Past 12 months', 'Past 5 years', 'Since joining CAF']
women = [4.8, 10.4, 27.3]
men = [1.2, 2.0, 3.8]
total = [1.7, 3.1, 7.1]

# the label locations
x = np.arange(len(categories))

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Width of the bars
bar_width = 0.2

# Setting position of bar on X axis
r1 = np.arange(len(women))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Make the plot
ax.bar(r1, women, color='tab:blue', width=bar_width, edgecolor='grey', label='Women')
ax.bar(r2, men, color='tab:orange', width=bar_width, edgecolor='grey', label='Men')
ax.bar(r3, total, color='tab:green', width=bar_width, edgecolor='grey', label='Total')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Time Period')
ax.set_ylabel('Percentage (%)')
ax.set_title('Incidents of Sexual Assault by Time Period and Gender')
ax.set_xticks([r + bar_width for r in range(len(women))])
ax.set_xticklabels(categories)
ax.legend()

# Add percentages on top of the bars
for i in ax.patches:
    ax.text(i.get_x() + i.get_width()/2, i.get_height() + 0.1, \
            f'{i.get_height():.2f}%', fontsize=11, color='dimgrey',
                rotation=0, ha='center')

# Show the figure
plt.tight_layout()
plt.show()

# %% [markdown]
# Unwanted sexual touching was the most common form of sexual assault reported by Regular Force members, with about 840 Regular Force members, or 1.5%, stating that they were victims of unwanted sexual touching in the past 12 months. This was higher than the proportion who reported being sexually attacked (0.3%) or being subjected to sexual activity to which they were unable to consent (0.2%).
#
# Of all Regular Force members who were victims of sexual assault in the past 12 months, about three-quarters (77%) reported that they were victims of unwanted sexual touching and no other type of sexual assault (Chart 2). Male victims were more likely than female victims to have experienced unwanted sexual touching and no other type (80% versus 71%). While a smaller proportion of victims reported sexual attacks and no other type (7%) or sexual activity to which they were unable to consent and no other type (4%), 12% were victims of more than one type of sexual assault.Note7 Women who were victims of sexual assault were more likely than male victims to report being the victim of more than one type of sexual assault (15% versus 11%).

# %%
# Let's create a pie chart to visualize the types of sexual assault and their corresponding percentages.

# Data
types_of_assault = [
    'Sexual attacks and no other type',
    'Sexual activity to which the victim is unable to consent and no other type',
    'Multiple types of sexual assault',
    'Unwanted sexual touching and no other type'
]
percentages = [7, 4, 12, 77]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(percentages, labels=types_of_assault, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title('Types of Sexual Assault in the Canadian Armed Forces (2016)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the pie chart
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-3f6f9f65340d>:19: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # Women more likely to be sexually assaulted by a supervisor; men by a peer
#
# Half (49%) of female Regular Force members who were victims of sexual assault in the past 12 months indicated that a supervisor or someone of a higher rank was the perpetrator, compared to just over one-third of male victims (36%) (Table 3; Chart 3). In contrast, sexual assault committed by a peer was more common among male victims (56% compared to 42% of female victims). Further, 6% of Regular Force members who were victims of sexual assault indicated that the perpetrator was an intimate partner (dating partner, spouse, or common-law partner) who was also a CAF member or DND employee or contractor, a proportion that was similar for male and female victims.Note13 A similar proportion of men and women who were victims of sexual assault in the military workplace or involving military members stated that the perpetrator was a stranger (9% and 7%E, respectively).

# %%
# Let's create a horizontal bar chart to visualize the relationship of perpetrators to women and men in reported incidents of sexual assault.

import matplotlib.pyplot as plt
import numpy as np

# Data
relationships = ['Other', 'Stranger', 'Intimate Partner', 'Subordinate', 'Peer', 'Supervisor or Higher Rank']
percent_women = [10, 7, 7, 13, 42, 49]
percent_men = [8, 9, 5, 25, 56, 36]

bar_width = 0.35  # width of the bars
index = np.arange(len(relationships))

fig, ax = plt.subplots(figsize=(12, 8))

bar1 = ax.barh(index, percent_women, bar_width, label='Women', color='lightblue')
bar2 = ax.barh(index + bar_width, percent_men, bar_width, label='Men', color='blue')

# Add some text for labels, title and custom y-axis tick labels, etc.
ax.set_ylabel('Relationship to Respondent')
ax.set_xlabel('Percentage')
ax.set_title('Relationship of Perpetrator in Sexual Assault Incidents')
ax.set_yticks(index + bar_width / 2)
ax.set_yticklabels(relationships)
ax.legend()

# Function to attach a text label next to each bar, displaying its width.
def autolabel(bars):
    for bar in bars:
        width = bar.get_width()
        ax.annotate('{}'.format(width),
                    xy=(width, bar.get_y() + bar.get_height() / 2),
                    xytext=(3, 0),  # 3 points horizontal offset
                    textcoords="offset points",
                    ha='left', va='center')

autolabel(bar1)
autolabel(bar2)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # One-quarter of sexual assault victims reported to someone in authority
#
# Approximately one in four (23%) victims of sexual assault in the past 12 months reported at least one incident to someone in authority. The majority (59%) of victims did not report their sexual assault to anyone in authority, while the remainder (18%) did not know if anyone in authority found out about the incident(s) in any way. Sexual attacks were more likely to be brought to the attention of someone in authority (35%) than incidents of unwanted sexual touching (21%) or sexual activity to which the victim was unable to consent (21%). Female Regular Force members who were victims of sexual assault were more likely to report their victimization to someone in authority when compared to male victims (29% versus 20%).

# %%
# Visualizing the reasons for not reporting incidents to authority, with specific colors for women and men as requested.

reasons = [
    "Other",
    "Concerns about formal complaint process",
    "Afraid of negative consequences",
    "Behaviour stopped",
    "Did not believe it would make a difference",
    "Not serious enough",
    "Resolved on my own"
]
percent_women = [18, 18, 35, 26, 25, 23, 43]
percent_men = [25, 7, 14, 22, 22, 40, 41]

y = np.arange(len(reasons))  # the label locations

fig, ax = plt.subplots(figsize=(10, 7))

bar_width = 0.35  # the width of the bars
rects1 = ax.barh(y - bar_width/2, percent_women, bar_width, label='Women', color='lightblue')
rects2 = ax.barh(y + bar_width/2, percent_men, bar_width, label='Men', color='blue')

ax.set_xlabel('Percentage')
ax.set_title('Reasons for Not Reporting Sexual Assault')
ax.set_yticks(y)
ax.set_yticklabels(reasons)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %% [markdown]
# # Sexualized behaviours
# Witnessing (i.e., seeing or hearing) or experiencing sexualized behaviour in the workplace was common among Regular Force members, with four in five (79%) stating that they had witnessed or experienced at least one of the ten types of sexualized behaviour in the past 12 months. Inappropriate verbal or non-verbal communication was by far the most frequent type of behaviour, reported by 78% of Regular Force members. Physical contact or sexual relationships and behaviours involving sexually explicit materials were less common, reported by 15% and 14% of Regular Force members, respectively.
# More specifically, sexual jokes were the most common type of sexualized behaviour reported by Regular Force members (76%), followed by inappropriate sexual comments (39%) and inappropriate discussions about sex life (34%). In contrast, smaller proportions of Regular Force members stated that they had witnessed or experienced repeated pressure for dates or sexual relationships (4%), taking or posting inappropriate or suggestive photos of any CAF members without consent (3%), or offering workplace benefits in exchange for sexual activity or mistreatment for not engaging in sexual activity (2%).
#
# Not only were sexual jokes the most commonly reported type of sexual behaviour in the workplace, they also tended to occur more frequently than other types of behaviour. Nearly half (46%) of Regular Force members who reported sexual jokes occurring in the workplace stated that this behaviour occurred ten or more times in the past 12 months, well above the proportion for any other type of behaviour

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
behaviors = ["Workplace benefits", "Repeated pressure for dates", "Photos or videos without consent",
             "Indecent exposure", "Unwanted contact", "Sexually explicit materials",
             "Unwanted sexual attention", "Discussion about sex life", "Sexual comments", "Sexual jokes"]
percent_women = [2, 8, 4, 6, 20, 13, 27, 40, 45, 78]
percent_men = [2, 3, 3, 7, 9, 13, 17, 33, 38, 76]

# Positions of the bars on the y-axis
y_pos = np.arange(len(behaviors))

# Creating the horizontal bar chart
plt.figure(figsize=(10, 8))
plt.barh(y_pos - 0.2, percent_women, 0.4, color='lightblue', label='Women')
plt.barh(y_pos + 0.2, percent_men, 0.4, color='blue', label='Men')

# Adding labels and customizing the chart
plt.xlabel('Percentage')
plt.title('Type of Sexualized Behaviour Experienced by Women and Men')
plt.yticks(y_pos, behaviors)
plt.legend()

# Display the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# # Discriminatory behaviours
# Compared to sexualized behaviours, witnessing or experiencing discriminatory behaviours in the workplace was less common among Regular Force members. That said, about one-third (34%) of all Regular Force members, indicated that discriminatory comments or statements on the basis of sex, sexual orientation, or gender identity were made within the past 12 months (Table 5). Discrimination on the basis of sex (32%) was more commonly reported than discrimination based on sexual orientation or gender identity (10%).Note31 More specifically, suggestions that people do not act like men or women should act (22%) and comments that people are not good at or should not have their jobs because of their sex (18%) were the most common discriminatory behaviours reported by Regular Force members.
#
# # Women report discrimination on the basis of sex, sexual orientation, or gender identity more frequently than men
#
# Witnessing or experiencing discriminatory behaviours in the workplace was more common among female Regular Force members, with 45% of women and 32% of men reporting such behaviours in the past 12 months. This difference held when looking both at discrimination on the basis of sex (42% of women versus 30% of men) and on the basis of sexual orientation or gender identity (16% versus 9%).
#
# More specifically, women were more likely to see, hear, or experience each of the five discriminatory behaviours measured by the survey. The largest difference was noted when it came to someone being insulted, mistreated, ignored, or excluded because of their sex, which was reported by 24% of women compared to 9% of men.
#
# # Perceived offensiveness of sexualized or discriminatory behaviours in the workplace
# Beyond observing or experiencing the behaviours in the workplace, the way in which they are interpreted is also an important consideration. In addition to asking CAF members if they had ever seen, heard, or experienced sexualized or discriminatory behaviours in the workplace, the SSMCAF also asked if they considered these to be offensive.
#
# Sexual jokes, the most prevalent behaviour, were perceived to be the least offensive, with 10% of Regular Force members who reported sexual jokes stating that they were somewhat or very offensive (Chart 6). In contrast, many of the less-frequently reported behaviours were perceived by Regular Force members to be the most offensive. For instance, while the offering of workplace benefits in exchange for engaging in sexual activity or workplace mistreatment for not engaging in sexual activity was the least common sexualized behaviour, reported by 2% of Regular Force members, 51% of those who witnessed or experienced it perceived it to be offensive, more than any other sexualized behaviour measured in the survey.

# %%
# Given the request for a visualization including both sets of data as bars, let's create a grouped bar chart.

behaviors = [
    "Workplace benefits", "Photos or videos without consent", "Repeated pressure for dates",
    "Discrimination based on gender identity", "Indecent exposure",
    "Discrimination based on sexual orientation", "Unwanted contact", "Mistreatment due to sex",
    "Sexually explicit materials", "Comments about sex and job suitability",
    "Unwanted sexual attention", "Stereotyping based on sex",
    "Inappropriate discussion about sex life", "Inappropriate sexual comments", "Sexual jokes"
]

witnessed_or_experienced = [2, 3, 4, 5, 7, 8, 10, 11, 13, 18, 18, 22, 34, 39, 76]
believed_offensive = [51, 42, 47, 58, 33, 62, 45, 63, 29, 48, 32, 35, 26, 32, 10]

x = np.arange(len(behaviors))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(12, 8))
rects1 = ax.barh(x - width/2, witnessed_or_experienced, width, label='Witnessed/Experienced', color='lightblue')
rects2 = ax.barh(x + width/2, believed_offensive, width, label='Believed Offensive', color='blue')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Percentage (%)')
ax.set_title('Sexualized or Discriminatory Behaviour Witnessed/Experienced vs. Believed Offensive')
ax.set_yticks(x)
ax.set_yticklabels(behaviors)
ax.legend()

fig.tight_layout()

plt.show()

# %%
# Given the new dataset provided, let's create a visualization comparing the percentages of women and men
# who have witnessed or experienced various sexualized or discriminatory behaviors.

# Data Preparation
behaviors = [
    "Workplace benefits", "Photos or videos without consent", "Repeated pressure for dates",
    "Discrimination based on gender identity", "Indecent exposure",
    "Discrimination based on sexual orientation", "Unwanted contact", "Mistreatment due to sex",
    "Sexually explicit materials", "Comments about sex and job suitability",
    "Unwanted sexual attention", "Stereotyping based on sex",
    "Inappropriate discussion about sex life", "Inappropriate sexual comments", "Sexual jokes"
]
percent_women = [81, 64, 65, 74, 54, 76, 60, 78, 52, 73, 51, 57, 43, 49, 19]
percent_men = [46, 37, 39, 54, 30, 58, 40, 57, 25, 41, 27, 30, 23, 29, 9]

# Visualization
fig, ax = plt.subplots(figsize=(12, 8))

# Plotting
y_pos = np.arange(len(behaviors))
ax.barh(y_pos - 0.2, percent_women, 0.4, color='lightblue', label='Women')
ax.barh(y_pos + 0.2, percent_men, 0.4, color='blue', label='Men')

# Customizing the plot
ax.set_xlabel('Percentage (%)')
ax.set_title('Sexualized or Discriminatory Behaviour Witnessed/Experienced by Gender')
ax.set_yticks(y_pos)
ax.set_yticklabels(behaviors)
ax.legend()

plt.tight_layout()
plt.show()

# %%
# Visualizing the reported experiences of sexualized behaviors by age group and gender.

# Data
age_groups = [
    "24 years and under", "25 to 29 years", "30 to 34 years",
    "35 to 39 years", "40 to 44 years", "45 to 49 years",
    "50 years and over"
]
percent_women = [54, 43, 36, 30, 25, 21, 19]
percent_men = [22, 21, 19, 14, 10, 8, 6]

# Setting up the plot
fig, ax = plt.subplots(figsize=(10, 7))

# Plotting
y_pos = np.arange(len(age_groups))
bars1 = ax.barh(y_pos - 0.2, percent_women, 0.4, color='lightblue', label='Women')
bars2 = ax.barh(y_pos + 0.2, percent_men, 0.4, color='blue', label='Men')

# Customizing the plot
ax.set_xlabel('Percentage (%)')
ax.set_title('Sexualized Behaviours Witnessed/Experienced by Age Group and Gender')
ax.set_yticks(y_pos)
ax.set_yticklabels(age_groups)
ax.legend()

# Adding data labels
for bar in bars1 + bars2:
    width = bar.get_width()
    label_x_pos = bar.get_x() + width + 1
    ax.text(label_x_pos, bar.get_y() + bar.get_height()/2., s=f'{width}%', va='center')

plt.tight_layout()
plt.show()

# %%
# Visualizing the type of emotional impact experienced by women and men.

# Data preparation
emotional_impacts = [
    "None", "Not much", "Other", "Suicidal thoughts", "Guilty", "Fearful", "Ashamed",
    "Depressed", "Lowered self-esteem", "Anxious", "Hurt/disappointment",
    "Shock/disbelief", "Loss of trust", "Upset", "More cautious/aware",
    "Angry", "Frustrated", "Annoyed"
]
percent_women = [32, 38, 18, 3, 11, 14, 16, 16, 25, 25, 39, 39, 41, 41, 45, 56, 56, 67]
percent_men = [75, 25, 8, 1, 3, 4, 6, 6, 9, 6, 10, 11, 12, 12, 13, 15, 16, 25]

# Visualization setup
fig, ax = plt.subplots(figsize=(14, 10))

# Plotting
y_pos = np.arange(len(emotional_impacts))
bars1 = ax.barh(y_pos - 0.2, percent_women, 0.4, label='Women', color='lightblue')
bars2 = ax.barh(y_pos + 0.2, percent_men, 0.4, label='Men', color='blue')

# Customizing the plot
ax.set_xlabel('Percentage (%)')
ax.set_title('Emotional Impact Experienced by Gender')
ax.set_yticks(y_pos)
ax.set_yticklabels(emotional_impacts)
ax.legend()

plt.tight_layout()
plt.show()

# %%
# Adjusting the provided visualization code to change the color of specific bars ("Total - outside the military workplace" and "Total - in the military workplace") to blue.

# Re-defining the data with a clear distinction for coloring specific bars
locations = [
    "Married quarters", "Street/public place", "Other location outside military",
    "Commercial/institutional", "Private residence", "Total - outside military",
    "Military college", "Outside Canada posting", "On an aircraft",
    "On a ship at sea/in port", "Other military workplace", "Office off base",
    "While deployed", "Sanctioned event", "Other training",
    "Temporary duty/attached posting", "Barracks/single quarters",
    "Course in military school", "Field exercises", "At the mess", "Military base/wing",
    "Total - in military workplace"
]

percentages = [
    9, 18, 19, 21, 30, 45, 2, 2, 5, 12, 12, 12, 13, 14, 17, 18, 20, 23, 31, 35, 85, 98
]

colors = ['lightblue'] * len(locations)  # Default color
# Change color for specific bars
colors[locations.index("Total - outside military")] = 'blue'
colors[locations.index("Total - in military workplace")] = 'blue'

# Visualization
fig, ax = plt.subplots(figsize=(10, 12))

# Creating the bar plot with customized colors
ax.barh(locations, percentages, color=colors)

# Customizing the plot
ax.set_xlabel('Percentage (%)')
ax.set_title('Location of Sexual Misconduct Occurrences')
ax.invert_yaxis()  # Invert the y-axis to have the highest percentages at the top

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
behaviors = [
    "Inappropriate communication",
    "Sexually explicit materials",
    "Physical contact/suggested sexual relations",
    "Discrimination based on sex",
    "Discrimination based on sexual orientation/gender identity"
]

# Percentages
came_to_attention = [21, 16, 19, 21, 20]
did_not_come_to_attention = [45, 47, 57, 48, 51]
unknown_if_found_out = [34, 37, 23, 31, 29]

x = np.arange(len(behaviors))  # the label locations

# Plot configuration
fig, ax = plt.subplots(figsize=(14, 8))
bar_width = 0.25  # the width of the bars

# Setting position of bar on X axis
r1 = np.arange(len(behaviors))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Making the plot
ax.bar(r1, came_to_attention, color='lightblue', width=bar_width, edgecolor='grey', label='Came to the attention of someone in authority')
ax.bar(r2, did_not_come_to_attention, color='blue', width=bar_width, edgecolor='grey', label='Did not come to the attention of someone in authority')
ax.bar(r3, unknown_if_found_out, color='red', width=bar_width, edgecolor='grey', label='Do not know anyone authority found out')

# Adding labels
ax.set_xlabel('Type of Behaviour', fontweight='bold')
ax.set_ylabel('Percentages', fontweight='bold')
ax.set_title('Awareness of Authority Regarding Behaviors')
ax.set_xticks([r + bar_width for r in range(len(behaviors))])
ax.set_xticklabels(behaviors, rotation=45, ha='right')
ax.legend()

fig.tight_layout()

# Show the plot
plt.show()
